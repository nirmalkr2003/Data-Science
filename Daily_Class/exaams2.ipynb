# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("emp.csv")
df
# Out:
#    EmployeeID    Name Department  Gender  Salary  Age  Experience
# 0           1    John         IT    Male   50000   28           3
# 1           2    Jane         HR  Female   60000   32           5
# 2           3     Bob    Finance    Male   55000   29           4
# 3           4   Alice         IT  Female   52000   26           2
# 4           5     Tom         HR    Male   58000   35           7
# 5           6    Lily    Finance  Female   62000   31           6
# 6           7   James         IT    Male   51000   27           3
# 7           8   Susan         HR  Female   59000   30           5
# 8           9  Robert    Finance    Male   63000   33           8
# 9          10   Karen         IT  Female   84000   29          11

# %%
df[df['Department']=='Finance']
# Out:
#    EmployeeID    Name Department  Gender  Salary  Age  Experience
# 2           3     Bob    Finance    Male   55000   29           4
# 5           6    Lily    Finance  Female   62000   31           6
# 8           9  Robert    Finance    Male   63000   33           8

# %%
df[df['Salary']>70000]
# Out:
#    EmployeeID   Name Department  Gender  Salary  Age  Experience
# 9          10  Karen         IT  Female   84000   29          11

# %%
df[['Name','Age','Salary']]
# Out:
#      Name  Age  Salary
# 0    John   28   50000
# 1    Jane   32   60000
# 2     Bob   29   55000
# 3   Alice   26   52000
# 4     Tom   35   58000
# 5    Lily   31   62000
# 6   James   27   51000
# 7   Susan   30   59000
# 8  Robert   33   63000
# 9   Karen   29   84000

# %%
df.sort_values(by='Experience',ascending=False).head(3)
# Out:
#    EmployeeID    Name Department  Gender  Salary  Age  Experience
# 9          10   Karen         IT  Female   84000   29          11
# 8           9  Robert    Finance    Male   63000   33           8
# 4           5     Tom         HR    Male   58000   35           7

# %%
df.nlargest(3,'Experience')
# Out:
#    EmployeeID    Name Department  Gender  Salary  Age  Experience
# 9          10   Karen         IT  Female   84000   29          11
# 8           9  Robert    Finance    Male   63000   33           8
# 4           5     Tom         HR    Male   58000   35           7

# %%
df['Salary'].mean()
# Out:
# np.float64(59400.0)

# %%
df.groupby('Department')['Age'].mean()
# Out:
# Department
# Finance    31.000000
# HR         32.333333
# IT         27.500000
# Name: Age, dtype: float64

# %%
df['Salary'].max(),df['Salary'].min()
# Out:
# (np.int64(84000), np.int64(50000))

# %%
df['Salary'].agg([max,min])
# Out:
# C:\Users\nirma\AppData\Local\Temp\ipykernel_25516\1869713071.py:1: FutureWarning: The provided callable <built-in function max> is currently using Series.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   df['Salary'].agg([max,min])
# C:\Users\nirma\AppData\Local\Temp\ipykernel_25516\1869713071.py:1: FutureWarning: The provided callable <built-in function min> is currently using Series.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
#   df['Salary'].agg([max,min])
# max    84000
# min    50000
# Name: Salary, dtype: int64

# %%
df['Department'].value_counts()
# Out:
# Department
# IT         4
# HR         3
# Finance    3
# Name: count, dtype: int64

# %%
salary=np.array(df['Salary'])
print(salary.mean())
print(np.median(salary))
print(salary.std())
# Out:
# 59400.0
# 58500.0
# 9275.774900244183

# %%
salary_arr=df['Salary'].to_numpy()
print(salary_arr)
# Out:
# [50000 60000 55000 52000 58000 62000 51000 59000 63000 84000]

# %%
df['Salary']=df['Salary']*1.10

# %%
age=df['Age'].to_numpy()
mean_age=np.mean(age)
print(mean_age)
df[df['Age']>mean_age]
# Out:
# 30.0
#    EmployeeID    Name Department  Gender   Salary  Age  Experience
# 1           2    Jane         HR  Female  66000.0   32           5
# 4           5     Tom         HR    Male  63800.0   35           7
# 5           6    Lily    Finance  Female  68200.0   31           6
# 8           9  Robert    Finance    Male  69300.0   33           8

# %%
empcount=df['Department'].value_counts()
sns.barplot(x=empcount.index,y=empcount.values)
plt.xlabel()
# Out:
# <Axes: xlabel='Department'>

# %%
plt.hist(df['Age'])
# Out:
# (array([1., 1., 1., 2., 1., 1., 1., 1., 0., 1.]),
#  array([26. , 26.9, 27.8, 28.7, 29.6, 30.5, 31.4, 32.3, 33.2, 34.1, 35. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.plot(df['Salary'],df['Experience'],marker='o')

# %%
deptcount=df['Department'].value_counts()
plt.pie(deptcount.values,labels=deptcount.index,autopct='%1.1f%%')
plt.legend()

# %%
sns.boxplot(y=df['Salary'])
# Out:
# <Axes: ylabel='Salary'>
