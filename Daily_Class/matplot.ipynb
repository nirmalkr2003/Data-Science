# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4, 5]
y = [2, 4, 6, 2, 1.5]

plt.plot(x, y)
plt.title("Line Plot")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.show()

# %%
categories = ["A", "B", "C", "D"]
values = [3, 7, 5, 6]

plt.bar(categories, values)
plt.title("Bar Chart")
plt.show()

# %%
x = [5, 7, 8, 7, 6, 9, 5, 6]
y = [99, 86, 87, 88, 100, 86, 103, 87]

plt.scatter(x, y)
plt.title("Scatter Plot")
plt.show()

# %%
import numpy as np

data = np.random.randn(1000)

plt.hist(data, bins=30, color="skyblue", edgecolor="black")
plt.title("Histogram")
plt.show()

# %%
sizes = [30, 25, 20, 15, 10]
labels = ["A", "B", "C", "D", "E"]

plt.pie(sizes, labels=labels, autopct="%1.1f%%")
plt.title("Pie Chart")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ages = np.random.randint(1, 81, 100)


plt.hist(ages, bins=8, color="skyblue", edgecolor="black")
plt.title("Histogram of Ages")
plt.xlabel("Age Groups")
plt.ylabel("Number of People")
plt.show()

# %%
import pandas as pd
df=pd.read_csv("Iris.csv")
plt.hist(df['SepalLengthCm'],bins=20,color='skyblue',edgecolor='black')
plt.title('sepal length Distribution')
plt.xlabel('sepal len ')
plt.ylabel('freq')
# plt.show()
# Out:
# Text(0, 0.5, 'freq')

# %%
df1=df.groupby('Species').count()['SepalWidthCm'].reset_index()
print(df1)
# Out:
#            Species  SepalWidthCm
# 0      Iris-setosa            50
# 1  Iris-versicolor            50
# 2   Iris-virginica            50

# %%
df1=df.groupby('Species').count()['Id'].reset_index()
print(df1)
# Out:
#            Species  Id
# 0      Iris-setosa  50
# 1  Iris-versicolor  50
# 2   Iris-virginica  50

# %%
df[['SepalWidthCm','PetalWidthCm']].hist(bins=20, figsize=(10,4), color='green', edgecolor='black')
plt.show()

# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df=sns.load_dataset('tips')
print(df.head())
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
print(df.tail())
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2

# %%
print(df.info)
# Out:
# <bound method DataFrame.info of      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]>

# %%
df.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
df.isnull().sum()
# Out:
# total_bill    0
# tip           0
# sex           0
# smoker        0
# day           0
# time          0
# size          0
# dtype: int64

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
sns.histplot(df['total_bill'],kde=True,bins=20,color='green',edgecolor='red')
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
print(df['day'].unique())
# Out:
# ['Sun', 'Sat', 'Thur', 'Fri']
# Categories (4, object): ['Thur', 'Fri', 'Sat', 'Sun']

# %%
sns.countplot(x='day',data=df,hue='day',legend=True)
plt.title("count of records by day")
plt.legend(loc='upper left') 
plt.show()

# %%
sns.scatterplot(x='total_bill',y='tip',data=df,hue='sex')
plt.title("scatter plot and totalbill")
# Out:
# Text(0.5, 1.0, 'scatter plot and totalbill')

# %%
sns.lineplot(x='size',y='tip',data=df,ci=None)
plt.title("Line plot of tip vs size")
plt.show()
# Out:
# C:\Users\nirma\AppData\Local\Temp\ipykernel_14296\632067528.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(x='size',y='tip',data=df,ci=None)

# %%
sns.lineplot(x='size',y='tip',data=df,err_style='bars')
plt.title("Line plot of tip vs size")
plt.show()

# %%
sns.pairplot(df,hue='sex')

# %%
corr=df.corr(numeric_only=True)
sns.heatmap(corr,annot=True)
plt.title("Correlation matrix")
# Out:
# Text(0.5, 1.0, 'Correlation matrix')

# %%
height=[150,160,165,185]
weight =[70,80,90,100]
calories_burnt=[65,75,95,99]

fig,ax=plt.subplots(nrows=2,ncols=3,figsize=(10,6))

ax[0,0].plot(calories_burnt,'go--')

ax[0,1].plot(weight)
ax[0,1].set_title("calories Burnt")

ax[0,1].set_xticks(ticks=[0,1,2]);

# %%
sizes=[15,30,45,10]
labels=['category a','category b','category c','category d']
exp = [0.4, 0, 0, 0]

# %%
plt.pie(sizes,labels=labels,
        autopct='%1f%%',
        shadow=True,explode=exp
        )
plt.legend(title="Categories",loc="best")

# %%
df=sns.load_dataset("iris")

# %%
sns.boxplot([df['sepal_length']])
# Out:
# <Axes: >

# %%
sns.boxplot(df)
# Out:
# <Axes: >

# %%
plt.boxplot([df['sepal_length']])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1bbf5028310>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1bbf4d7b150>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1bbf4c51b90>],
#  'medians': [<matplotlib.lines.Line2D at 0x1bbf5066c50>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1bbf4cee5d0>],
#  'means': []}

# %%
df.boxplot()
# Out:
# <Axes: >

# %%
sns.violinplot(df['sepal_length'])
# Out:
# <Axes: ylabel='sepal_length'>

# %%
sns.violinplot(df)
# Out:
# <Axes: >

# %%
plt.violinplot(df['sepal_length'])
# Out:
# {'bodies': [<matplotlib.collections.FillBetweenPolyCollection at 0x1bbf538c410>],
#  'cmaxes': <matplotlib.collections.LineCollection at 0x1bbf530ec90>,
#  'cmins': <matplotlib.collections.LineCollection at 0x1bbf5e9ac50>,
#  'cbars': <matplotlib.collections.LineCollection at 0x1bbf1e50b10>}

# %%
sns.violinplot(x='sepal_length',y='species',data=df)
# Out:
# <Axes: xlabel='sepal_length', ylabel='species'>

# %%
import pandas as pd

import  numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df=pd.read_csv("forbes.csv")

# %%
df.head()
# Out:
#    rank                personName   age  finalWorth  year  month  \
# 0     1                 Elon Musk  50.0    219000.0  2022      4
# 1     2                Jeff Bezos  58.0    171000.0  2022      4
# 2     3  Bernard Arnault & family  73.0    158000.0  2022      4
# 3     4                Bill Gates  66.0    129000.0  2022      4
# 4     5            Warren Buffett  91.0    118000.0  2022      4
#
#                 category              source        country       state  ...  \
# 0             Automotive       Tesla, SpaceX  United States       Texas  ...
# 1             Technology              Amazon  United States  Washington  ...
# 2       Fashion & Retail                LVMH         France         NaN  ...
# 3             Technology           Microsoft  United States  Washington  ...
# 4  Finance & Investments  Berkshire Hathaway  United States    Nebraska  ...
#
#                        organization selfMade gender   birthDate  \
# ...

# %%
print(df.shape)
# Out:
# (2668, 22)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2668 entries, 0 to 2667
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   rank                  2668 non-null   int64
#  1   personName            2668 non-null   object
#  2   age                   2582 non-null   float64
#  3   finalWorth            2668 non-null   float64
#  4   year                  2668 non-null   int64
#  5   month                 2668 non-null   int64
#  6   category              2668 non-null   object
#  7   source                2668 non-null   object
#  8   country               2655 non-null   object
#  9   state                 748 non-null    object
#  10  city                  2624 non-null   object
#  11  countryOfCitizenship  2668 non-null   object
#  12  organization          352 non-null    object
#  13  selfMade              2668 non-null   bool
#  14  gender                2652 non-null   object
# ...

# %%
print(df.columns)
print(df.describe)
# Out:
# Index(['rank', 'personName', 'age', 'finalWorth', 'year', 'month', 'category',
#        'source', 'country', 'state', 'city', 'countryOfCitizenship',
#        'organization', 'selfMade', 'gender', 'birthDate', 'title',
#        'philanthropyScore', 'residenceMsa', 'numberOfSiblings', 'bio',
#        'about'],
#       dtype='object')
# <bound method NDFrame.describe of       rank                personName   age  finalWorth  year  month  \
# 0        1                 Elon Musk  50.0    219000.0  2022      4
# 1        2                Jeff Bezos  58.0    171000.0  2022      4
# 2        3  Bernard Arnault & family  73.0    158000.0  2022      4
# 3        4                Bill Gates  66.0    129000.0  2022      4
# 4        5            Warren Buffett  91.0    118000.0  2022      4
# ...    ...                       ...   ...         ...   ...    ...
# 2663  2578             Zhang Yuqiang  66.0      1000.0  2022      4
# ...

# %%
df.tail()
# Out:
#       rank               personName   age  finalWorth  year  month  \
# 2663  2578            Zhang Yuqiang  66.0      1000.0  2022      4
# 2664  2578               Zhou Ruxin  59.0      1000.0  2022      4
# 2665  2578        Wen Zhou & family  57.0      1000.0  2022      4
# 2666  2578     Zhou Yifeng & family  43.0      1000.0  2022      4
# 2667  2578  Zhuang Kuilong & family  59.0      1000.0  2022      4
#
#            category                   source country state  ... organization  \
# 2663  Manufacturing               Fiberglass   China   NaN  ...          NaN
# 2664     Technology               Navigation   China   NaN  ...          NaN
# 2665  Manufacturing                chemicals   China   NaN  ...          NaN
# 2666         Energy  liquefied petroleum gas   China   NaN  ...          NaN
# 2667  Manufacturing                polyester   China   NaN  ...          NaN
#
#      selfMade gender   birthDate title philanthropyScore residenceMsa  \
# ...

# %%
print(df.isnull().sum())
# Out:
# rank                       0
# personName                 0
# age                       86
# finalWorth                 0
# year                       0
# month                      0
# category                   0
# source                     0
# country                   13
# state                   1920
# city                      44
# countryOfCitizenship       0
# organization            2316
# selfMade                   0
# gender                    16
# birthDate                 99
# title                   2267
# philanthropyScore       2272
# residenceMsa            2029
# numberOfSiblings        2541
# bio                        0
# about                   1106
# dtype: int64

# %%
df1=df.dropna()
# print(df1)
df1.isnull().sum()
# Out:
# rank                    0
# personName              0
# age                     0
# finalWorth              0
# year                    0
# month                   0
# category                0
# source                  0
# country                 0
# state                   0
# city                    0
# countryOfCitizenship    0
# organization            0
# selfMade                0
# gender                  0
# birthDate               0
# title                   0
# philanthropyScore       0
# residenceMsa            0
# numberOfSiblings        0
# bio                     0
# about                   0
# dtype: int64

# %%
df2=df.loc[:,['rank','personName','age','finalWorth','category','country','gender']]
# print(df2.isnull().sum())
df2
# Out:
#       rank                personName   age  finalWorth               category  \
# 0        1                 Elon Musk  50.0    219000.0             Automotive
# 1        2                Jeff Bezos  58.0    171000.0             Technology
# 2        3  Bernard Arnault & family  73.0    158000.0       Fashion & Retail
# 3        4                Bill Gates  66.0    129000.0             Technology
# 4        5            Warren Buffett  91.0    118000.0  Finance & Investments
# ...    ...                       ...   ...         ...                    ...
# 2663  2578             Zhang Yuqiang  66.0      1000.0          Manufacturing
# 2664  2578                Zhou Ruxin  59.0      1000.0             Technology
# 2665  2578         Wen Zhou & family  57.0      1000.0          Manufacturing
# 2666  2578      Zhou Yifeng & family  43.0      1000.0                 Energy
# 2667  2578   Zhuang Kuilong & family  59.0      1000.0          Manufacturing
#
#             country gender
# ...

# %%
df2.isnull().sum()
# Out:
# rank           0
# personName     0
# age           86
# finalWorth     0
# category       0
# country       13
# gender        16
# dtype: int64

# %%
df2=df2.dropna()
df2.isnull()
# Out:
#        rank  personName    age  finalWorth  category  country  gender
# 0     False       False  False       False     False    False   False
# 1     False       False  False       False     False    False   False
# 2     False       False  False       False     False    False   False
# 3     False       False  False       False     False    False   False
# 4     False       False  False       False     False    False   False
# ...     ...         ...    ...         ...       ...      ...     ...
# 2663  False       False  False       False     False    False   False
# 2664  False       False  False       False     False    False   False
# 2665  False       False  False       False     False    False   False
# 2666  False       False  False       False     False    False   False
# 2667  False       False  False       False     False    False   False
#
# [2568 rows x 7 columns]

# %%
df2.isnull().sum()
# Out:
# rank          0
# personName    0
# age           0
# finalWorth    0
# category      0
# country       0
# gender        0
# dtype: int64

# %%
df2['gender'].value_counts()
# Out:
# gender
# M    2282
# F     286
# Name: count, dtype: int64

# %%
sns.countplot(x='gender',data=df,hue=df['gender'])
# Out:
# <Axes: xlabel='gender', ylabel='count'>

# %%
df2['country'].unique()
# Out:
# array(['United States', 'France', 'India', 'Mexico', 'China', 'Singapore',
#        'Spain', 'Canada', 'Germany', 'Switzerland', 'Belgium',
#        'Hong Kong', 'United Kingdom', 'Australia', 'Austria', 'Italy',
#        'Japan', 'Bahamas', 'Indonesia', 'Chile', 'Russia', 'Sweden',
#        'Czechia', 'Monaco', 'United Arab Emirates', 'Nigeria', 'Denmark',
#        'Thailand', 'Malaysia', 'Brazil', 'Colombia', 'New Zealand',
#        'South Korea', 'South Africa', 'Philippines', 'Egypt', 'Taiwan',
#        'Israel', 'Vietnam', 'Poland', 'Norway', 'Cayman Islands',
#        'Netherlands', 'Eswatini (Swaziland)', 'Peru', 'Algeria',
#        'Kazakhstan', 'Georgia', 'Portugal', 'British Virgin Islands',
#        'Turkey', 'Finland', 'Ukraine', 'Ireland', 'Bermuda', 'Lebanon',
#        'Argentina', 'Cambodia', 'Oman', 'Guernsey', 'Liechtenstein',
#        'Turks and Caicos Islands', 'Qatar', 'Morocco', 'Uruguay',
#        'Slovakia', 'Romania', 'Nepal', 'Tanzania', 'Bahrain', 'Greece',
# ...

# %%
turkey_data = df2[df2['country']=='Turkey']
print(turkey_data['gender'].value_counts())
# Out:
# gender
# M    19
# F     4
# Name: count, dtype: int64

# %%
avg_salary = df.groupby('category')['finalWorth'].mean().reset_index().head(5)
print(avg_salary)
# Out:
#                      category   finalWorth
# 0                  Automotive  8337.142857
# 1  Construction & Engineering  2693.478261
# 2                 Diversified  5230.555556
# 3                      Energy  4182.105263
# 4            Fashion & Retail  6468.800000

# %%
sns.barplot(x='category',y='finalWorth',data=avg_salary,hue='category')
# Out:
# <Axes: xlabel='category', ylabel='finalWorth'>

# %%
top10 = df2.sort_values(by='finalWorth', ascending=False).head(10)
print(top10[['personName', 'finalWorth']])
# Out:
#                  personName  finalWorth
# 0                 Elon Musk    219000.0
# 1                Jeff Bezos    171000.0
# 2  Bernard Arnault & family    158000.0
# 3                Bill Gates    129000.0
# 4            Warren Buffett    118000.0
# 5                Larry Page    111000.0
# 6               Sergey Brin    107000.0
# 7             Larry Ellison    106000.0
# 8             Steve Ballmer     91400.0
# 9             Mukesh Ambani     90700.0

# %%
sns.barplot(x='finalWorth', y='personName', data=top10)
# Out:
# <Axes: xlabel='finalWorth', ylabel='personName'>

# %%
top_country = df2.groupby('country').size().sort_values(ascending=False).head(1)
print(top_country)
# Out:
# country
# United States    742
# dtype: int64

# %%
import matplotlib.pyplot as plt
import numpy as np

# Generate random values
x = np.arange(1, 16)              # X-axis values from 1 to 10
y = np.random.randint(10, 100, 15) # Random Y values between 10 and 100

# Plot the line graph
plt.plot(x, y, marker='o', linestyle='-', color='b')

# Add labels and title
plt.xlabel("X-axis")
plt.ylabel("Random Values")
plt.title("Line Plot with Random Values")

# Show the plot
plt.show()
